# %%
# 연습문제 :네이버 영화 리뷰 모으기

#Step 1. 필요한 모듈과 라이브러리를 로딩합니다.

from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.service import Service

import time
import sys
import math
import numpy  
import pandas as pd 
import os
import random

print("=" *80)
print("연습문제 :네이버 영화 리뷰 정보 수집하기 ")
print("=" *80)

query_txt = input('1.크롤링 할 영화의 제목을 입력하세요: ')
query_url = 'https://movie.naver.com'

cnt = int(input('2.크롤링 할 리뷰건수는 몇건입니까?: '))
page_cnt = math.ceil(cnt / 10)

f_dir = input("3.파일을 저장할 폴더명만 쓰세요(예:c:\\py_temp\\):")
if f_dir =='' :
    f_dir='c:\\py_temp\\'
    
print("-" *80)
print("요청하신 데이터를 수집 중이오니 잠시만 기다려 주세요~~~~")

# 저장될 파일위치와 이름을 지정합니다
now = time.localtime()
s = '%04d-%02d-%02d-%02d-%02d-%02d' % (now.tm_year, now.tm_mon, now.tm_mday, now.tm_hour, now.tm_min, now.tm_sec)
os.makedirs(f_dir+s+'-'+query_txt)
os.chdir(f_dir+s+'-'+query_txt)

ff_name=f_dir+s+'-'+query_txt+'\\'+s+'-'+query_txt+'.txt'
fc_name=f_dir+s+'-'+query_txt+'\\'+s+'-'+query_txt+'.csv'
fx_name=f_dir+s+'-'+query_txt+'\\'+s+'-'+query_txt+'.xls'

#Step 3. 크롬 드라이버를 사용해서 웹 브라우저를 실행합니다.
s_time = time.time( )

s = Service("c:/py_temp/chromedriver.exe")
driver = webdriver.Chrome(service=s)

driver.get(query_url)
driver.maximize_window()
time.sleep(2)

# 영화 제목으로 검색
element = driver.find_element(By.ID,"ipt_tx_srch")
element.send_keys(query_txt)
driver.find_element(By.XPATH,'//*[@id="jSearchArea"]/div/button').click()
driver.find_element(By.XPATH,'//*[@id="old_content"]/ul[2]/li/dl/dt/a').click()
        
#Step 4 평점 옵션 버튼 클릭
driver.find_element(By.LINK_TEXT,"평점").click()

#Step 5. 현재 페이지 리뷰와 점수 등 내용 수집
# IFRAME 변경
driver.switch_to.frame('pointAfterListIframe')

html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')

#현재 총 리뷰 건수를 확인하여 사용자의 요청건수와 비교 후 동기화
result= soup.find('div', class_='score_total').find('strong','total').find('em').get_text()

print("=" *80)
search_cnt = int(result.replace(",",""))

if cnt > search_cnt :
    cnt = search_cnt

print("전체 검색 결과 건수 :",search_cnt,"건")
print("실제 최종 출력 건수",cnt)

print("\n")
page_cnt = math.ceil(cnt / 10)
print("크롤링 할 총 페이지 번호: ",page_cnt)
print("=" *80)


score2=[]
review2=[]
writer2=[]
wdate2=[]
gogam2=[]
g_gogam2=[]
b_gogam2=[]
dwlist2=[]

count = 0         # 크롤링 건수 카운트 변수
click_count = 1   # 페이지 번호

while ( click_count <= page_cnt )  :
            
            html = driver.page_source
            soup = BeautifulSoup(html, 'html.parser')
            
            score_result = soup.find('div', class_='score_result').find('ul')
            slist = score_result.find_all('li')

            for li in slist:

                count += 1
                
                f = open(ff_name, 'a',encoding='UTF-8')
            
                print("\n")
                print("총 %s 건 중 %s 번째 리뷰 데이터를 수집합니다==============" %(cnt,count))
                score = li.find('div', class_='star_score').find('em').get_text()
                print("1.별점:","*"*int(score),": ", score)
                score2.append(score)
                f.write("\n")
                f.write("총 %s 건 중 %s 번째 리뷰 데이터를 수집합니다==============" %(cnt,count) + "\n")
                f.write("1.별점:"+score + "\n")
            
                review = li.find('div', class_='score_reple').find('p').get_text().replace('\n','').strip()
                print("2.리뷰내용:",review)
                f.write("2.리뷰내용:" + review + "\n")
                review2.append(review)
         
                dwlist = li.find('div',class_='score_reple').find_all('em')
                writer = dwlist[0].find('span').get_text()
                print("3.작성자:",writer)
                f.write("3.작성자:" + writer + "\n")
                writer2.append(writer)
                
                wdate = dwlist[1].text
                print('4.작성일자:',wdate)
                f.write("4.작성일자:" + wdate + "\n")
                wdate2.append(wdate)
            
                gogam = li.find('div', class_='btn_area').find_all('strong')
                g_gogam = gogam[0].text
                print('5.공감:',g_gogam)
                f.write("5.공감:" + g_gogam + "\n")
                g_gogam2.append(g_gogam)
                
                b_gogam = gogam[1].text
                print('6.비공감:', b_gogam)
                f.write("6.비공감:" + b_gogam + "\n")
                b_gogam2.append(b_gogam)
                
                if count == cnt :
                    break
            
            time.sleep(random.randrange(1,2))  

            click_count += 1
            
            if click_count > page_cnt :
                break
            else :
                driver.find_element(By.LINK_TEXT,"%s" %click_count).click()

            time.sleep(random.randrange(1,2))  # 3-8 초 사이에 랜덤으로 시간 선택

#Step 11. xls 형태와 csv 형태로 저장하기
naver_movie = pd.DataFrame()
naver_movie['별점(평점)']=score2
naver_movie['리뷰내용']=review2
naver_movie['작성자']=writer2
naver_movie['작성일자']=wdate2
naver_movie['공감횟수']=g_gogam2
naver_movie['비공감횟수']=b_gogam2

# csv 형태로 저장하기
naver_movie.to_csv(fc_name,encoding="utf-8-sig",index=True)

# 엑셀 형태로 저장하기
naver_movie.to_excel(fx_name ,index=True,engine='openpyxl')

e_time = time.time( )
t_time = e_time - s_time

print("\n") 
print("=" *80)
print("1.요청된 총 %s 건의 리뷰 중에서 실제 크롤링 된 리뷰수는 %s 건입니다" %(cnt,count))
print("2.총 소요시간은 %s 초 입니다 " %round(t_time,1))
print("3.파일 저장 완료: txt 파일명 : %s " %ff_name)
print("4.파일 저장 완료: csv 파일명 : %s " %fc_name)
print("5.파일 저장 완료: xls 파일명 : %s " %fx_name)
print("=" *80)

driver.close( )
# Out:
# ================================================================================
# 연습문제 :네이버 영화 리뷰 정보 수집하기
# ================================================================================
# 1.크롤링 할 영화의 제목을 입력하세요: 극한직업
# 2.크롤링 할 리뷰건수는 몇건입니까?: 30
# 3.파일을 저장할 폴더명만 쓰세요(예:c:\py_temp\):
# --------------------------------------------------------------------------------
# 요청하신 데이터를 수집 중이오니 잠시만 기다려 주세요~~~~
# ================================================================================
# 전체 검색 결과 건수 : 47253 건
# 실제 최종 출력 건수 30
#
#
# 크롤링 할 총 페이지 번호:  3
# ================================================================================
#
#
# 총 30 건 중 1 번째 리뷰 데이터를 수집합니다==============
# 1.별점: ********** :  10
# 2.리뷰내용: 일단 진선규님 진짜 연기를 다양하게 잘하셔서 놀랐어요 오랜만에 부담없이 진짜 코미디 영화를 본거 같아서 즐거웠어요 조조로 할인받고 봤는데 반값이라 더 재밌어요 밤새다 할거없이 봤는데 최고~~
# 3.작성자: 신해인(godl****)
# 4.작성일자: 2019.01.23 11:45
# 5.공감: 10704
# 6.비공감: 1034
#
#
#
#
# 총 30 건 중 2 번째 리뷰 데이터를 수집합니다==============
# 1.별점: ******** :  8
# 2.리뷰내용: 관람객																																																												류승룡 드디어 심폐소생술 성공!
# 3.작성자: 조희송(vhif****)
# 4.작성일자: 2019.01.23 11:37
# 5.공감: 8914
# 6.비공감: 895
#
#
#
#
# 총 30 건 중 3 번째 리뷰 데이터를 수집합니다==============
# 1.별점: ********** :  10
# 2.리뷰내용: 관람객																																																												진짜 뻥안치고 ㅈㄴ 웃겼다
# 3.작성자: 냐미냐미(sc2j****)
# 4.작성일자: 2019.01.23 12:47
# 5.공감: 9083
# 6.비공감: 1302
#
#
#
#
# 총 30 건 중 4 번째 리뷰 데이터를 수집합니다==============
# 1.별점: ********** :  10
# 2.리뷰내용: 관람객																																																												계속 웃으면서 봤어요!"지금까지 이런맛은 없었다이것은 갈비인가 통닭인가수원왕갈비통닭입니다."이 대사가 귓가에 계속 맴도네요 ㅎㅎ
# 3.작성자: 아람(flya****)
# 4.작성일자: 2019.01.23 14:48
# 5.공감: 7323
# 6.비공감: 753
#
#
#
#
# 총 30 건 중 5 번째 리뷰 데이터를 수집합니다==============
# 1.별점: ********** :  10
# 2.리뷰내용: 지금까지 이런 영화는 없었다  이것은 영화인가 통닭광고인가
# 3.작성자: 박광숙(gwan****)
# 4.작성일자: 2019.01.23 20:16
# 5.공감: 7003
# 6.비공감: 639
#
#
#
#
# 총 30 건 중 6 번째 리뷰 데이터를 수집합니다==============
# 1.별점: ********** :  10
# 2.리뷰내용: 간만에 정치색 안띠고 마냥 한국식으로 웃긴 영화다~류승룡도 완전 찰지고ㅋ흥해라
# 3.작성자: 11234567(kui8****)
# 4.작성일자: 2019.01.23 14:47
# 5.공감: 6123
# 6.비공감: 644
#
#
#
#
# 총 30 건 중 7 번째 리뷰 데이터를 수집합니다==============
# 1.별점: ******** :  8
# 2.리뷰내용: 아주그냥  진지한척 심오한척 메세지있는척 겉멋은잔뜩들고 막상 까보면 텅빈 영화들만 주구장창 나와서 피로하던참에 간만에 힘 쪽빼고 유쾌하게 웃으며 볼수있는영화라 너무 즐거웠습니다. 한국식코미디에는 꼭 나오는 억지 감동...
# 3.작성자: STONE9(revo****)
# 4.작성일자: 2019.01.23 18:00
# 5.공감: 5350
# 6.비공감: 536
#
#
#
#
# 총 30 건 중 8 번째 리뷰 데이터를 수집합니다==============
# 1.별점: ********** :  10
# 2.리뷰내용: 류승룡 좀비설 너무 웃겼어여
# 3.작성자: ksg3****
# 4.작성일자: 2019.01.23 17:32
# 5.공감: 4589
# 6.비공감: 427
#
#
#
#
# 총 30 건 중 9 번째 리뷰 데이터를 수집합니다==============
# 1.별점: ********** :  10
# 2.리뷰내용: 마약반 형사들 각각 캐릭터가 확실했습니다. 겹치는 점도 없었고 조합도 너무 좋았습니다. 악역분들도 그 표정들하며 사투리와 찰진 욕설들.. 기억속에 남습니다. 웃으면서 행복했던 감정이 기억에 남습니다. 시사회로 봤지만...
# 3.작성자: 박진이(qwes****)
# 4.작성일자: 2019.01.23 09:26
# 5.공감: 4518
# 6.비공감: 523
#
#
#
#
# 총 30 건 중 10 번째 리뷰 데이터를 수집합니다==============
# 1.별점: ********** :  10
# 2.리뷰내용: 관람객																																																												완전 내스타일.. 류승룡 영화 요즘 말아먹더니 이번엔 대박 웃기네 ㅋㅋ역시 갓승룡
# 3.작성자: 샤랄랄라라(lrv3****)
# 4.작성일자: 2019.01.23 12:48
# 5.공감: 3988
# 6.비공감: 521
#
#
#
#
# 총 30 건 중 11 번째 리뷰 데이터를 수집합니다==============
# 1.별점: ********** :  10
# 2.리뷰내용: 조조로 보고 출근중입니다. 저는 정말 미친듯이 웃었고.감동도조금 있었습니다.극한직업2 제작해주떼엽
# 3.작성자: love****
# 4.작성일자: 2019.01.23 11:42
# 5.공감: 3154
# 6.비공감: 511
#
#
#
#
# 총 30 건 중 12 번째 리뷰 데이터를 수집합니다==============
# 1.별점: ********** :  10
# 2.리뷰내용: 류승룡: 여보 왜씻어....?
# 3.작성자: next****
# 4.작성일자: 2019.01.23 20:53
# 5.공감: 2850
# 6.비공감: 250
#
#
#
#
# 총 30 건 중 13 번째 리뷰 데이터를 수집합니다==============
# 1.별점: ********* :  9
# 2.리뷰내용: 관람객																																																												자꾸 광고할떄 치킨치킨 거리길래 뭔말인가 했더만..ㅋㅋㅋ치킨먹고싶네
# 3.작성자: 쏠(99pa****)
# 4.작성일자: 2019.01.23 11:42
# 5.공감: 2580
# 6.비공감: 339
#
#
#
#
# 총 30 건 중 14 번째 리뷰 데이터를 수집합니다==============
# 1.별점: ********** :  10
# 2.리뷰내용: ㅎㅎㅎㅎ 2시간 내내 웃기다.신파도 없고 재밌다.한번더 보러 가야겠다
# 3.작성자: 엑스칼리버(ohch****)
# 4.작성일자: 2019.01.23 13:22
# 5.공감: 2419
# 6.비공감: 347
#
#
#
#
# 총 30 건 중 15 번째 리뷰 데이터를 수집합니다==============
# 1.별점: ********** :  10
# 2.리뷰내용: 진선규ㅋㅋㅋ나보다 못생겼단말이 얼마나 상처받던지
# 3.작성자: 진용이(kore****)
# 4.작성일자: 2019.01.23 21:01
# 5.공감: 2175
# 6.비공감: 222
#
#
#
#
# 총 30 건 중 16 번째 리뷰 데이터를 수집합니다==============
# 1.별점: ********** :  10
# 2.리뷰내용: 관람객																																																												올해 가장 재미있었다 아직까진
# 3.작성자: 생각중(rlae****)
# 4.작성일자: 2019.01.23 13:02
# 5.공감: 2293
# 6.비공감: 361
#
#
#
#
# 총 30 건 중 17 번째 리뷰 데이터를 수집합니다==============
# 1.별점: ******* :  7
# 2.리뷰내용: 방금보고 나옵니다 이하늬 커플이 다했습니다 ㅋㅋ
# 3.작성자: kikitt(jjhh****)
# 4.작성일자: 2019.01.23 11:09
# 5.공감: 2333
# 6.비공감: 457
#
#
#
#
# 총 30 건 중 18 번째 리뷰 데이터를 수집합니다==============
# 1.별점: ***** :  5
# 2.리뷰내용: 유머코드가 맞냐 안맞냐의 차이.같이 간 친구는 계속 웃던데, 저는 그냥 그랬어요.
# 3.작성자: 쏭(anud****)
# 4.작성일자: 2019.01.27 17:23
# 5.공감: 2530
# 6.비공감: 770
#
#
#
#
# 총 30 건 중 19 번째 리뷰 데이터를 수집합니다==============
# 1.별점: ****** :  6
# 2.리뷰내용: 글쎄.. 그낭그랬는데 나만그런가?
# 3.작성자: 빈사마(gusq****)
# 4.작성일자: 2019.01.26 03:28
# 5.공감: 2694
# 6.비공감: 1016
#
#
#
#
# 총 30 건 중 20 번째 리뷰 데이터를 수집합니다==============
# 1.별점: ********** :  10
# 2.리뷰내용: 마지막에 공명 안아파~ 너무 웃겨
# 3.작성자: jeep****
# 4.작성일자: 2019.01.23 14:15
# 5.공감: 1859
# 6.비공감: 219
#
#
#
#
# 총 30 건 중 21 번째 리뷰 데이터를 수집합니다==============
# 1.별점: ********* :  9
# 2.리뷰내용: 어떻게든 웃기려고 하는데 이만하면 성공하지 않았을까 ㅋㅋ
# 3.작성자: 소원열차(alst****)
# 4.작성일자: 2019.01.23 11:46
# 5.공감: 1915
# 6.비공감: 322
#
#
#
#
# 총 30 건 중 22 번째 리뷰 데이터를 수집합니다==============
# 1.별점: * :  1
# 2.리뷰내용: 진짜 모르겠음 ㅠㅠ 개그코드 안맞으면 재미없나봐요... 웃기려고 해서 안웃김요ㅠㅠ나만 안웃긴가봄 다들 재밌다고 깔깔
# 3.작성자: daeu****
# 4.작성일자: 2019.01.28 22:19
# 5.공감: 2864
# 6.비공감: 1376
#
#
#
#
# 총 30 건 중 23 번째 리뷰 데이터를 수집합니다==============
# 1.별점: ********* :  9
# 2.리뷰내용: 글래스가 낫다 비공 vs 극한직업이 괜첞않다 공감 좀요 ㅜㅠㅠ 부탁드릴께요 네티즌 여러분들
# 3.작성자: 박종훈(jong****)
# 4.작성일자: 2019.01.23 17:46
# 5.공감: 2016
# 6.비공감: 583
#
#
#
#
# 총 30 건 중 24 번째 리뷰 데이터를 수집합니다==============
# 1.별점: * :  1
# 2.리뷰내용: 나랑은 안맞는듯 너무 억지로 웃길려고 발악하는 느낌
# 3.작성자: V왕(dlwo****)
# 4.작성일자: 2019.01.25 19:47
# 5.공감: 2798
# 6.비공감: 1448
#
#
#
#
# 총 30 건 중 25 번째 리뷰 데이터를 수집합니다==============
# 1.별점: ********** :  10
# 2.리뷰내용: 치킨으로 이렇게 웃기기 있기 없기?
# 3.작성자: 키가크다(ba2z****)
# 4.작성일자: 2019.01.23 11:43
# 5.공감: 1672
# 6.비공감: 326
#
#
#
#
# 총 30 건 중 26 번째 리뷰 데이터를 수집합니다==============
# 1.별점: ********** :  10
# 2.리뷰내용: 관람객																																																												ㅠㅠ진짜웃곀ㅋㅋㅋ 또볼꺼야ㅠㅠㅠ
# 3.작성자: 령(tpaz****)
# 4.작성일자: 2019.01.23 12:48
# 5.공감: 1569
# 6.비공감: 299
#
#
#
#
# 총 30 건 중 27 번째 리뷰 데이터를 수집합니다==============
# 1.별점: ********** :  10
# 2.리뷰내용: 진짜 개재밌음 꼭 보삼 류승룡씨는 오랜만에 흥행성공 하시겠네
# 3.작성자: 김태훈(redc****)
# 4.작성일자: 2019.01.23 13:13
# 5.공감: 1297
# 6.비공감: 234
#
#
#
#
# 총 30 건 중 28 번째 리뷰 데이터를 수집합니다==============
# 1.별점: ********** :  10
# 2.리뷰내용: 감히 천만 예상 해 봅니다같은 생각 따봉ㄱㄱ
# 3.작성자: 김주호(rlaw****)
# 4.작성일자: 2019.01.23 22:27
# 5.공감: 1282
# 6.비공감: 237
#
#
#
#
# 총 30 건 중 29 번째 리뷰 데이터를 수집합니다==============
# 1.별점: ****** :  6
# 2.리뷰내용: 웃음코드가 나랑 안맞음...
# 3.작성자: 징징(jim7****)
# 4.작성일자: 2019.01.29 00:02
# 5.공감: 1553
# 6.비공감: 508
#
#
#
#
# 총 30 건 중 30 번째 리뷰 데이터를 수집합니다==============
# 1.별점: ********** :  10
# 2.리뷰내용: 염력보고 충격받아서 류승룡 이번 영화 괜찮을까 망설였는데 ㅋㅋㅋ처음부터 끝까지 너무 웃김 ㅋㅋㅋㅋ영화관에서 다들 깔깔깔웃던데 ㅋㅋ스토리도 나름 탄탄함 ㅋㅋㅋ
# 3.작성자: 인기쟁이(nays****)
# 4.작성일자: 2019.01.23 15:14
# 5.공감: 1121
# 6.비공감: 205
#
#
#
#
# ================================================================================
# 1.요청된 총 30 건의 리뷰 중에서 실제 크롤링 된 리뷰수는 30 건입니다
# 2.총 소요시간은 18.1 초 입니다
# 3.파일 저장 완료: txt 파일명 : c:\py_temp\2022-03-21-16-45-42-극한직업\2022-03-21-16-45-42-극한직업.txt
# 4.파일 저장 완료: csv 파일명 : c:\py_temp\2022-03-21-16-45-42-극한직업\2022-03-21-16-45-42-극한직업.csv
# 5.파일 저장 완료: xls 파일명 : c:\py_temp\2022-03-21-16-45-42-극한직업\2022-03-21-16-45-42-극한직업.xls
# ================================================================================
