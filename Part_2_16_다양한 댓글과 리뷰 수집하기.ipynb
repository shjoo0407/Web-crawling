# %%
# Chap 16. 다양한 댓글 모으기
# 뉴스 기사의 댓글 모으기 - 미세먼지 / 스모그  
# 테스트 기사 URL : https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=102&oid=056&aid=0010661268

#Step 1. 필요한 모듈과 라이브러리를 로딩합니다.
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.service import Service
import time
import math
import numpy  
import pandas as pd  
import random
import os
import re

#Step 2. 사용자에게 검색어 키워드를 입력 받고 저장할 폴더와 파일명을 설정합니다.
print("=" *80)
print(" Chap 16.뉴스 기사의 댓글 정보  수집하기")
print("=" *80)
print("\n")

query_txt = '뉴스기사댓글'
query_url = input('1.댓글을 크롤링할 뉴스의 URL을 입력하세요: ')
cnt = int(input('2.크롤링 할 건수는 몇건입니까?(10건단위로 입력): '))
page_cnt = math.ceil(cnt / 20)

f_dir = input("3.파일을 저장할 폴더명만 쓰세요(예:c:\\py_temp\\):")
if f_dir=='' :
    f_dir='c:\\py_temp\\'
    
# 저장될 파일위치와 이름을 지정합니다
now = time.localtime()
s = '%04d-%02d-%02d-%02d-%02d-%02d' % (now.tm_year, now.tm_mon, now.tm_mday, now.tm_hour, now.tm_min, now.tm_sec)

os.makedirs(f_dir+s+'-'+query_txt)
os.chdir(f_dir+s+'-'+query_txt)

ff_name=f_dir+s+'-'+query_txt+'\\'+s+'-'+query_txt+'.txt'
fc_name=f_dir+s+'-'+query_txt+'\\'+s+'-'+query_txt+'.csv'
fx_name=f_dir+s+'-'+query_txt+'\\'+s+'-'+query_txt+'.xls'

#Step 3. 크롬 드라이버를 사용해서 웹 브라우저를 실행합니다.
s_time = time.time( )

s = Service("c:/py_temp/chromedriver.exe")
driver = webdriver.Chrome(service=s)

driver.get(query_url)
driver.maximize_window()
time.sleep(5)

#Step 4. 현재 총 리뷰 건수를 확인하여 사용자의 요청건수와 비교 후 동기화합니다
html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')

result= soup.find('div', class_='u_cbox_head').find('span','u_cbox_count')
result2 = result.get_text()

print("=" *80)
result3 = result2.replace(",","")
result4 = re.search("\d+",result3)
search_cnt = int(result4.group())

if cnt > search_cnt :
    cnt = search_cnt

print("전체 검색 결과 건수 :",search_cnt,"건")
print("실제 최종 출력 건수",cnt)
print("실체 출력될 최종 페이지수" , page_cnt)

# Step 5. 사용자가 요청한 건수가 많을 경우 리뷰 더보기 버튼을 클릭합니다
# 최초 10건 수집후 댓글 더보기 버튼 클릭
# 아래 버튼을 눌러 첫 화면에 총 20건의 댓글이 나오게 만듦
driver.find_element(By.XPATH,'//*[@id="cbox_module"]/div/div[9]/a/span[1]').click()
time.sleep(3)

#Step 6. 20건 출력되어 있는 현재 페이지 리뷰와 점수 등 내용 수집
writer_id2=[]       # 리뷰 작성자 ID
review2=[]          # 리뷰 내용
write_date2=[]      # 리뷰 작성 일자
gogam_0=[]          # 공감 횟수
gogam_1=[]          # 비공감 횟수
count = 0

for a in range(1,page_cnt+1) :
    
    if a == page_cnt :
          break
    else :
        driver.find_element(By.XPATH,'//*[@id="cbox_module"]/div/div[9]/a').click() 
        time.sleep(3)
        print("%s페이지 이동 완료========================================================" %a)
        time.sleep(random.randrange(1,3))  # 3-8 초 사이에 랜덤으로 시간 선택

print('이제 리뷰 정보를 수집합니다. 잠시만 기다려 주세요~~~~~~~~')

#txt 파일에 저장하기 위해 파일 open하기
f = open(ff_name, 'a',encoding='UTF-8')

html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')

reple_result = soup.find('div', class_='u_cbox_content_wrap').find('ul')
slist = reple_result.find_all('li')

for li in slist:
    count += 1
    print("\n")
    print("총 %s건 중 %s번째 댓글 수집 중입니다 ==================" %(cnt,count))

    writer_id = li.find('span', class_='u_cbox_nick').get_text()
    print("1.작성자ID:", writer_id)
    f.write("\n")
    f.write("총 %s 건 중 %s 번째 리뷰 데이터를 수집합니다==============" %(cnt,count) + "\n")
    f.write("1.작성자ID:"+writer_id + "\n")
    writer_id2.append(writer_id)

    try :
        review = li.find('span', class_='u_cbox_contents').get_text()
    except AttributeError :
        review='작성자에 의해 삭제된 댓글입니다'
        print("2.리뷰 :",review)
    else :
        print("2.리뷰:",review)
    f.write("2.리뷰:" + review + "\n")
    review2.append(review)

    write_date = li.find('span',class_='u_cbox_date').get_text()
    print('3.작성일자:',write_date)
    f.write("3.작성일자:" + write_date + "\n")
    write_date2.append(write_date)

    gogam = li.find('div', class_='u_cbox_recomm_set').find_all('em')

    try :
        g_gogam = gogam[0].text
        print('4.공감:',g_gogam)
    except IndexError :
        g_gogam = '0'
        print('4.공감 :',g_gogam)
    f.write("4.공감:" + g_gogam + "\n")
    gogam_0.append(g_gogam)

    gogam = li.find('div', class_='u_cbox_recomm_set').find_all('em')

    try :
        b_gogam = gogam[1].text
        print('5.비공감:',b_gogam) 
    except IndexError :
        b_gogam = '0'
        print('5.비공감 :',b_gogam)
    f.write("5.비공감:" + b_gogam + "\n")
    gogam_1.append(b_gogam)
      
    time.sleep(0.2)      

    if count == cnt :
         break
                   
# 학습목표 3. 수집된 데이터를 표 형태로 저장하기
#Step 7. xls 형태와 csv 형태로 저장하기
news_reple = pd.DataFrame()
news_reple['작성자ID']=pd.Series(writer_id2)
news_reple['리뷰내용']=pd.Series(review2)
news_reple['작성일자']=pd.Series(write_date2)
news_reple['공감횟수']=pd.Series(gogam_0)
news_reple['비공감횟수']=pd.Series(gogam_1)

# csv 형태로 저장하기
news_reple.to_csv(fc_name,encoding="utf-8-sig",index=True)

# 엑셀 형태로 저장하기
news_reple.to_excel(fx_name ,index=True , engine='openpyxl')

# Step 8. 요약 정보 출력하기
e_time = time.time( )
t_time = e_time - s_time

print("\n") 
print("=" *120)
print("1.요청된 총 %s 건의 리뷰 중에서 실제 크롤링 된 리뷰수는 %s 건입니다" %(cnt,count))
print("2.총 소요시간은 %s 초 입니다 " %round(t_time,1))
print("3.파일 저장 완료: txt 파일명 : %s " %ff_name)
print("4.파일 저장 완료: csv 파일명 : %s " %fc_name)
print("5.파일 저장 완료: xls 파일명 : %s " %fx_name)
print("=" *120)

driver.close( )
# Out:
# ================================================================================
#  Chap 16.뉴스 기사의 댓글 정보  수집하기
# ================================================================================
#
#
# 1.댓글을 크롤링할 뉴스의 URL을 입력하세요: https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=102&oid=056&aid=0010661268
# 2.크롤링 할 건수는 몇건입니까?(10건단위로 입력): 75
# 3.파일을 저장할 폴더명만 쓰세요(예:c:\py_temp\):
# ================================================================================
# 전체 검색 결과 건수 : 505 건
# 실제 최종 출력 건수 75
# 실체 출력될 최종 페이지수 4
# 1페이지 이동 완료========================================================
# 2페이지 이동 완료========================================================
# 3페이지 이동 완료========================================================
# 이제 리뷰 정보를 수집합니다. 잠시만 기다려 주세요~~~~~~~~
#
#
# 총 75건 중 1번째 댓글 수집 중입니다 ==================
# 1.작성자ID: ehdd****
# 2.리뷰: 어떻게든 한국미세먼지 탓도있다고 보도하려고 애쓰네ㅋㅋ
# 3.작성일자: 2019.01.15. 16:10
# 4.공감: 2018
# 5.비공감: 56
#
#
# 총 75건 중 2번째 댓글 수집 중입니다 ==================
# 1.작성자ID: siho****
# 2.리뷰: 진짜 쓰레기 보다 못한 기사다 그래서 어쩌 자는거냐? 누가 심한거 모르냐? 정상 적인 언론이라면 지금에 미세먼지 원인이 뭐고 앞으로 나가야할 정부 정책에는 뭐가 있고 뭔가 대책과 무능한 정부에 질책이나 문제점을 쓰는게 맞을듯 싶은데 누가 미세먼지 나쁘다는것에 부정하는 사람있냐? 국민세금이 아깝다
# 3.작성일자: 2019.01.15. 16:26
# 4.공감: 725
# 5.비공감: 37
#
#
# 총 75건 중 3번째 댓글 수집 중입니다 ==================
# 1.작성자ID: reds****
# 2.리뷰: 충남공장 사진은 왜 올리는거지
# 3.작성일자: 2019.01.15. 16:38
# 4.공감: 519
# 5.비공감: 4
#
#
# 총 75건 중 4번째 댓글 수집 중입니다 ==================
# 1.작성자ID: daup****
# 2.리뷰 : 작성자에 의해 삭제된 댓글입니다
# 3.작성일자: 2019.12.05. 22:23
# 4.공감 : 0
# 5.비공감 : 0
#
#
# 총 75건 중 5번째 댓글 수집 중입니다 ==================
# 1.작성자ID: samk****
# 2.리뷰: 애쓴다ㅋㅋㅋㅋㅋㅋ
# 3.작성일자: 2019.01.15. 16:55
# 4.공감: 137
# 5.비공감: 7
#
#
# 총 75건 중 6번째 댓글 수집 중입니다 ==================
# 1.작성자ID: mark****
# 2.리뷰: 기자님. 잘 모르는건 대충 짐작으로 글 적지 마세요. 중간 충남 공장 사진에 오염물질을 뿜어대는 공장이라고 글을 다셨는데, 저거 거의 다 수증기입니다. TEMS 때문에 실시간 감시되서 오염물질 뿜어대질 못해요. 제대로 조사 안한 내용이나 모르는건 상상력으로 기사 적지 마세요. 그러니 잘 못된 기사가 나오고 뇌피셜 소리나 듣는겁니다.
# 3.작성일자: 2019.01.15. 17:27
# 4.공감: 71
# 5.비공감: 3
#
#
# 총 75건 중 7번째 댓글 수집 중입니다 ==================
# 1.작성자ID: dusc****
# 2.리뷰: 중국탓인줄 국민들은 다 압니다  바보로 알지 마세요
# 3.작성일자: 2019.01.15. 17:28
# 4.공감: 61
# 5.비공감: 2
#
#
# 총 75건 중 8번째 댓글 수집 중입니다 ==================
# 1.작성자ID: hubb****
# 2.리뷰 : 작성자에 의해 삭제된 댓글입니다
# 3.작성일자: 2020.03.12. 06:08
# 4.공감 : 0
# 5.비공감 : 0
#
#
# 총 75건 중 9번째 댓글 수집 중입니다 ==================
# 1.작성자ID: seun****
# 2.리뷰 : 작성자에 의해 삭제된 댓글입니다
# 3.작성일자: 2019.04.08. 11:04
# 4.공감 : 0
# 5.비공감 : 0
#
#
# 총 75건 중 10번째 댓글 수집 중입니다 ==================
# 1.작성자ID: kim7****
# 2.리뷰 : 작성자에 의해 삭제된 댓글입니다
# 3.작성일자: 2020.12.14. 16:01
# 4.공감 : 0
# 5.비공감 : 0
#
#
# 총 75건 중 11번째 댓글 수집 중입니다 ==================
# 1.작성자ID: rua0****
# 2.리뷰: 이정훈기자, 제가 몇번이나 말했는데..참...당신이 마지막에 써 놓은 중국발+국내발+기상조건 이라고 하는데.
# 이 3가지를 하나하나 퍼센트로 나누면 어떻게 될까요?
# 중국발이 몇퍼센트 차지하고 국내발 몇퍼센트 차지할거라고 보세요?
# 기상전문가에 미세먼지에 관심이 높으신 ‘한국인’기자님.
# 당신이 미세먼지에 관심이 많아서 몇년전부터 기사 쓴거 압니다.
# 당신이 말하고자 하는 합리적인 생각을 모르는게 아니에요.
# 국내발도 있다고 하는데, 있긴하겠죠. 근데 그거 줄여도 우리는 깨끗한공기 못마십니다.
# 기사에 쓰여있듯이, 윗공기 빨대도 빨아마셔야지요
# 3.작성일자: 2019.01.15. 17:25
# 4.공감: 28
# 5.비공감: 1
#
#
# 총 75건 중 12번째 댓글 수집 중입니다 ==================
# 1.작성자ID: jihy****
# 2.리뷰: 충남지역 공장말고 중국공장 사진도 올려주세요^^ 되도않는 헛소리 작작하시구요ㅎㅎ
# 3.작성일자: 2019.01.15. 17:22
# 4.공감: 24
# 5.비공감: 0
#
#
# 총 75건 중 13번째 댓글 수집 중입니다 ==================
# 1.작성자ID: summ****
# 2.리뷰 : 작성자에 의해 삭제된 댓글입니다
# 3.작성일자: 2019.07.10. 10:59
# 4.공감 : 0
# 5.비공감 : 0
#
#
# 총 75건 중 14번째 댓글 수집 중입니다 ==================
# 1.작성자ID: slsl****
# 2.리뷰: 중국이라는 말을 왜 못하는거냐? 세금 걷어가서 뭐하길래 환경부담금이다 자동차세다 뭐다 다 걷어가서는 왜 ㅈㄹ인데 애초에 걷어가지 말고 그러던가 그리고 어떻게든 국내 문제로 돌리려고 애쓰는것 같은데 기자야 장난하냐?! 국민들은 멍청이가 아니다
# 3.작성일자: 2019.01.15. 17:28
# 4.공감: 11
# 5.비공감: 0
#
#
# 총 75건 중 15번째 댓글 수집 중입니다 ==================
# 1.작성자ID: jhak****
# 2.리뷰 : 작성자에 의해 삭제된 댓글입니다
# 3.작성일자: 2019.01.15. 21:17
# 4.공감 : 0
# 5.비공감 : 0
#
#
# 총 75건 중 16번째 댓글 수집 중입니다 ==================
# 1.작성자ID: blas****
# 2.리뷰: 유독 KBS만 중국을 싸고 도네!
# 3.작성일자: 2019.01.15. 18:33
# 4.공감: 8
# 5.비공감: 0
#
#
# 총 75건 중 17번째 댓글 수집 중입니다 ==================
# 1.작성자ID: ziwh****
# 2.리뷰: KBS쓰레기방송
# 3.작성일자: 2019.01.15. 17:32
# 4.공감: 8
# 5.비공감: 0
#
#
# 총 75건 중 18번째 댓글 수집 중입니다 ==================
# 1.작성자ID: gago****
# 2.리뷰: 단순히 현재 상황 알려주려고 악조건속에서도 위험하게 헬기 촬영이 무슨 의미가 있는거냐!? 분석도 해결 방법 제시도 없는...
# 3.작성일자: 2019.01.15. 17:12
# 4.공감: 8
# 5.비공감: 2
#
#
# 총 75건 중 19번째 댓글 수집 중입니다 ==================
# 1.작성자ID: hyun****
# 2.리뷰: 진짜 어이없네 우리나라 80년대 버스 에서 시커먼 매연 내뿜고 공장 많을때도 하늘은 맑았다이걸 자꾸 국내요인 걸고 넘어지는데 말이 된다고 생각하나 진짜?
# 3.작성일자: 2019.01.15. 18:03
# 4.공감: 6
# 5.비공감: 0
#
#
# 총 75건 중 20번째 댓글 수집 중입니다 ==================
# 1.작성자ID: dlcn****
# 2.리뷰: 역시 국내문제로 몰아가는군.힘없는나라~밥줄생각안하는 노후경후차 단속하고 잘지켜지지도않는 2부제시행하고 패턴은 반복될거고
# 일본의 미세먼지 상황을봐라~왜 헬조선인지 알거다. 마스크 쓰고 놀고있던 아이들한테 미안한마음이 들더라
# 3.작성일자: 2019.01.15. 17:32
# 4.공감: 6
# 5.비공감: 0
#
#
# 총 75건 중 21번째 댓글 수집 중입니다 ==================
# 1.작성자ID: bern****
# 2.리뷰: 대통령님 그냥 솔직히 발표해요. 중국이 너무 강한 나라라서 잘못 건들면 우리 경제 파탄난다. 그리고 중국과 틀어지면 북한과도 다시 멀어진다. 국민 여러분 많이 힘드시죠? 저희가 어떻게든 해결책을 찾고 있으니 좀 더 힘내주십시오, 라고. 이 쉬운 말을 왜 못 합니까.. 지지율 떨어지는 거 무서우신 거죠? 손바닥으로 하늘을 가리세요. 떨어지면 더 잘해서 다시 올리는 게 대통령이예요
# 3.작성일자: 2019.01.16. 09:58
# 4.공감: 5
# 5.비공감: 0
#
#
# 총 75건 중 22번째 댓글 수집 중입니다 ==================
# 1.작성자ID: sush****
# 2.리뷰: Kbs  이와중에 충남아산공장사진 보여주네. ㅋㅋ 이런미세먼지는 중국이야
# 3.작성일자: 2019.01.15. 21:36
# 4.공감: 5
# 5.비공감: 0
#
#
# 총 75건 중 23번째 댓글 수집 중입니다 ==================
# 1.작성자ID: grea****
# 2.리뷰: 중국 96% 한국 4%임. 한국에 차량만 2000만대, 공장도 수백만개가 있는데 한국이 뿜어내는 오염물질이 없을 수가 없지.
# 3.작성일자: 2019.01.15. 20:25
# 4.공감: 5
# 5.비공감: 0
#
#
# 총 75건 중 24번째 댓글 수집 중입니다 ==================
# 1.작성자ID: cup9****
# 2.리뷰 : 작성자에 의해 삭제된 댓글입니다
# 3.작성일자: 2019.01.15. 22:27
# 4.공감 : 0
# 5.비공감 : 0
#
#
# 총 75건 중 25번째 댓글 수집 중입니다 ==================
# 1.작성자ID: yein****
# 2.리뷰 : 작성자에 의해 삭제된 댓글입니다
# 3.작성일자: 2020.03.19. 22:31
# 4.공감 : 0
# 5.비공감 : 0
#
#
# 총 75건 중 26번째 댓글 수집 중입니다 ==================
# 1.작성자ID: wass****
# 2.리뷰: 충남지역공장은 뭐냐??미세먼지 없는날도 저기 가동되는지 안되는지 올려라
# 3.작성일자: 2019.01.15. 17:24
# 4.공감: 5
# 5.비공감: 0
#
#
# 총 75건 중 27번째 댓글 수집 중입니다 ==================
# 1.작성자ID: mung****
# 2.리뷰 : 작성자에 의해 삭제된 댓글입니다
# 3.작성일자: 2019.04.30. 04:23
# 4.공감 : 0
# 5.비공감 : 0
#
#
# 총 75건 중 28번째 댓글 수집 중입니다 ==================
# 1.작성자ID: yo_9****
# 2.리뷰 : 작성자에 의해 삭제된 댓글입니다
# 3.작성일자: 2020.03.25. 13:53
# 4.공감 : 0
# 5.비공감 : 0
#
#
# 총 75건 중 29번째 댓글 수집 중입니다 ==================
# 1.작성자ID: nnni****
# 2.리뷰: 국내원인은 개소리다. 한중일 초미세먼지 예측영상보면 그냥 중국에서부터 서해바다 끼고 한반도까지 뻘건 고농도 초미세먼지가 그대로 연결되서 한반도를 직통한다. 국영방송이 이렇게 대놓고 ㅉㅉㅉ
# 3.작성일자: 2019.01.16. 07:01
# 4.공감: 4
# 5.비공감: 0
#
#
# 총 75건 중 30번째 댓글 수집 중입니다 ==================
# 1.작성자ID: mem0****
# 2.리뷰: 공중파들 얼마 받아쳐먹옸길래 은폐하고 왜곡하냐...???
# 3.작성일자: 2019.01.15. 23:29
# 4.공감: 4
# 5.비공감: 0
#
#
# 총 75건 중 31번째 댓글 수집 중입니다 ==================
# 1.작성자ID: dlaa****
# 2.리뷰 : 작성자에 의해 삭제된 댓글입니다
# 3.작성일자: 2019.01.18. 21:50
# 4.공감 : 0
# 5.비공감 : 0
#
#
# 총 75건 중 32번째 댓글 수집 중입니다 ==================
# 1.작성자ID: jhye****
# 2.리뷰 : 작성자에 의해 삭제된 댓글입니다
# 3.작성일자: 2019.01.15. 23:20
# 4.공감 : 0
# 5.비공감 : 0
#
#
# 총 75건 중 33번째 댓글 수집 중입니다 ==================
# 1.작성자ID: 202g****
# 2.리뷰: 국영방송이 시청료 춰먹고 미세먼지는 국내문제라고 난리치네ㅉㅉ이러니 어용언론ㆍ정부의 시녀
# 3.작성일자: 2019.01.15. 18:38
# 4.공감: 4
# 5.비공감: 0
#
#
# 총 75건 중 34번째 댓글 수집 중입니다 ==================
# 1.작성자ID: cheu****
# 2.리뷰: 공기에서 쓰레기 태운 냄새가......
# 3.작성일자: 2019.01.15. 18:22
# 4.공감: 4
# 5.비공감: 0
#
#
# 총 75건 중 35번째 댓글 수집 중입니다 ==================
# 1.작성자ID: guwa****
# 2.리뷰: 중국발 인정한것만 해도 발전한거네 국내문제라고 떠들더니 누가봐도 중국발이지 일본은 왜 깨끗한데 일본이 울나라 보다 차가 적어 공장이 적어
# 3.작성일자: 2019.01.15. 17:36
# 4.공감: 4
# 5.비공감: 0
#
#
# 총 75건 중 36번째 댓글 수집 중입니다 ==================
# 1.작성자ID: thru****
# 2.리뷰: 기자 니 애미 애비가 짱깨년놈이냐?
# 3.작성일자: 2019.01.15. 17:35
# 4.공감: 4
# 5.비공감: 0
#
#
# 총 75건 중 37번째 댓글 수집 중입니다 ==================
# 1.작성자ID: wash****
# 2.리뷰: 게이비에스 어떻게든 한국탓하려고 애쓴다
# 3.작성일자: 2019.01.15. 17:32
# 4.공감: 4
# 5.비공감: 0
#
#
# 총 75건 중 38번째 댓글 수집 중입니다 ==================
# 1.작성자ID: leso****
# 2.리뷰 : 작성자에 의해 삭제된 댓글입니다
# 3.작성일자: 2019.01.16. 07:00
# 4.공감 : 0
# 5.비공감 : 0
#
#
# 총 75건 중 39번째 댓글 수집 중입니다 ==================
# 1.작성자ID: ken8****
# 2.리뷰: 문재앙 찍어준 개돼지들은 불평할 자격없다
# 3.작성일자: 2019.01.15. 18:25
# 4.공감: 4
# 5.비공감: 1
#
#
# 총 75건 중 40번째 댓글 수집 중입니다 ==================
# 1.작성자ID: ggoo****
# 2.리뷰: 물타기하지마라!!!!    중국발 98%  한국발 2%
# 3.작성일자: 2019.01.16. 16:24
# 4.공감: 3
# 5.비공감: 0
#
#
# 총 75건 중 41번째 댓글 수집 중입니다 ==================
# 1.작성자ID: jgsb****
# 2.리뷰: 은근슬쩍 국내원인 끼워넣네~ㅋㅋㅋㅋ
# 3.작성일자: 2019.01.16. 05:34
# 4.공감: 3
# 5.비공감: 0
#
#
# 총 75건 중 42번째 댓글 수집 중입니다 ==================
# 1.작성자ID: yoon****
# 2.리뷰: 기자 논리가 맞으려면 우리나라는 1년 365일 1일같은 미세먼지여야한다 하지만 우리나라도 1년중에 미세먼지가 좋음 뜨는날이 있는데 그건 중국에서 바람이 안 불어올때다 ㅅㅂ
# 3.작성일자: 2019.01.16. 04:16
# 4.공감: 3
# 5.비공감: 0
#
#
# 총 75건 중 43번째 댓글 수집 중입니다 ==================
# 1.작성자ID: sehi****
# 2.리뷰: 국내 발생 미세먼지 탓도 분명있다. 근데 그걸 모르는 국민이있냐?? 이딴걸 기사라고 정성들여서 쓴거냐?? 금번 초유의 미세먼지 사태에서 인간적으로 국내미세먼지가 차지하는 비중이 얼마나 될거같냐? 정말 많이 잡아줘봐야 30% 되겠냐?? 언론의 개가 되지말아라 기자야 . 너도 먹고살아야하는건 알지만 양심에 어긋나는기사로 어설픈 선동질하지말란소리다
# 3.작성일자: 2019.01.16. 02:08
# 4.공감: 3
# 5.비공감: 0
#
#
# 총 75건 중 44번째 댓글 수집 중입니다 ==================
# 1.작성자ID: insi****
# 2.리뷰: 진짜 답답한게 앞쪽을 보면 뿌연 미세먼지인데 하늘을 위로 보면 분명 파란하늘이 가려져있는게 보임. 진짜 지옥에 있는거 같음. 마치 나치의 생화학 실험실에 있는 것처럼.
# 3.작성일자: 2019.01.15. 21:51
# 4.공감: 3
# 5.비공감: 0
# 총 75건 중 45번째 댓글 수집 중입니다 ==================
# 1.작성자ID: lang****
# 2.리뷰: 우리나라 300 넘어갈때는 무조건 중국 80%임 우리나라는 산업화가 이미 막바지 단계라 내부에서 진짜 심해봐야 80임 미세먼지 기준
# 3.작성일자: 2019.01.15. 21:46
# 4.공감: 3
# 5.비공감: 0
#
#
# 총 75건 중 46번째 댓글 수집 중입니다 ==================
# 1.작성자ID: alst****
# 2.리뷰: 아이구야..난 또 뭐라고..기사제목보고 완전 낚였네한국오염? 한국오염이라고 제발 한국인이 말하지 맙시다
# 원인은 궁금하지 않아요 우린 다 알거든요
# 이젠
# 실질적인 대책에 대해 말해봅시다
# 3.작성일자: 2019.01.15. 19:04
# 4.공감: 3
# 5.비공감: 0
#
#
# 총 75건 중 47번째 댓글 수집 중입니다 ==================
# 1.작성자ID: king****
# 2.리뷰: 애쓴다  기레기야  얼마  받았노
# 3.작성일자: 2019.01.15. 18:18
# 4.공감: 3
# 5.비공감: 0
#
#
# 총 75건 중 48번째 댓글 수집 중입니다 ==================
# 1.작성자ID: isp9****
# 2.리뷰 : 작성자에 의해 삭제된 댓글입니다
# 3.작성일자: 2020.03.04. 10:58
# 4.공감 : 0
# 5.비공감 : 0
#
#
# 총 75건 중 49번째 댓글 수집 중입니다 ==================
# 1.작성자ID: kkan****
# 2.리뷰 : 작성자에 의해 삭제된 댓글입니다
# 3.작성일자: 2019.01.16. 10:37
# 4.공감 : 0
# 5.비공감 : 0
#
#
# 총 75건 중 50번째 댓글 수집 중입니다 ==================
# 1.작성자ID: minh****
# 2.리뷰: 충남공장사진ㅋㅋㅋ 애쓰셨구요 기자님논리면 내일 -10도인데 충남공장+경유차+고등어 로인해 하늘이 뿌여야겠네요ㅋㅋㅋ내일봐봅시닼ㅋㅋ
# 3.작성일자: 2019.01.15. 17:24
# 4.공감: 3
# 5.비공감: 0
#
#
# 총 75건 중 51번째 댓글 수집 중입니다 ==================
# 1.작성자ID: metc****
# 2.리뷰: 90프로이상 중국탓이라고 왜 말못하냐
# 3.작성일자: 2019.01.16. 09:19
# 4.공감: 2
# 5.비공감: 0
#
#
# 총 75건 중 52번째 댓글 수집 중입니다 ==================
# 1.작성자ID: yame****
# 2.리뷰: 자한당이 KBS 수신료 반환거부 뭐한다고하지않았냐 ? ㅈㄴ동참하고싶네 OOO .
# 3.작성일자: 2019.01.16. 05:44
# 4.공감: 2
# 5.비공감: 0
#
#
# 총 75건 중 53번째 댓글 수집 중입니다 ==================
# 1.작성자ID: enig****
# 2.리뷰 : 작성자에 의해 삭제된 댓글입니다
# 3.작성일자: 2019.03.14. 19:45
# 4.공감 : 0
# 5.비공감 : 0
#
#
# 총 75건 중 54번째 댓글 수집 중입니다 ==================
# 1.작성자ID: ibei****
# 2.리뷰: 이정훈 기자였네요~~이기자  진짜 미세먼지 많을때마다 국내요인이라고  지속적으로 글쓰는 사람이예요
# 3.작성일자: 2019.01.15. 23:58
# 4.공감: 2
# 5.비공감: 0
#
#
# 총 75건 중 55번째 댓글 수집 중입니다 ==================
# 1.작성자ID: skld****
# 2.리뷰: 중국인은 사람모양을 한 바퀴벌레다
# 3.작성일자: 2019.01.15. 23:41
# 4.공감: 2
# 5.비공감: 0
#
#
# 총 75건 중 56번째 댓글 수집 중입니다 ==================
# 1.작성자ID: mayy****
# 2.리뷰: 무능정부 발암먼지 대책이나 좀 따져물어라.
# 3.작성일자: 2019.01.15. 22:14
# 4.공감: 2
# 5.비공감: 0
#
#
# 총 75건 중 57번째 댓글 수집 중입니다 ==================
# 1.작성자ID: rejy****
# 2.리뷰: 요즘은 정말 기자는 없고 기레기들만 넘쳐난다.
# 3.작성일자: 2019.01.15. 22:05
# 4.공감: 2
# 5.비공감: 0
#
#
# 총 75건 중 58번째 댓글 수집 중입니다 ==================
# 1.작성자ID: eung****
# 2.리뷰: 내가낸세금 미셰먼지저감에 꼭써라이대로가면 이민갈거니까
# 가습기며이트로 천식되고 먼지로 악화되고 비염도지고 아 못살겠다
# 학자는 뮈하나
# 연구비 당장왕창지원해 대책세워~~~
# 공무원 아무것도 몰라 중국에 항의도 못해 아는게 있어야하지
# 직무유기야 ~~
# 3.작성일자: 2019.01.15. 21:49
# 4.공감: 2
# 5.비공감: 0
#
#
# 총 75건 중 59번째 댓글 수집 중입니다 ==================
# 1.작성자ID: forc****
# 2.리뷰 : 작성자에 의해 삭제된 댓글입니다
# 3.작성일자: 2019.01.18. 23:46
# 4.공감 : 0
# 5.비공감 : 0
#
#
# 총 75건 중 60번째 댓글 수집 중입니다 ==================
# 1.작성자ID: 3607****
# 2.리뷰: 경유차량의 운행량은 항상 일정할텐데.. 어째서 미세먼지가 나타났다가 사라지는지 원인을 밝혀라!
# 3.작성일자: 2019.01.15. 19:51
# 4.공감: 2
# 5.비공감: 0
#
#
# 총 75건 중 61번째 댓글 수집 중입니다 ==================
# 1.작성자ID: angu****
# 2.리뷰: 경제는 힘들어서 숨 막히고 소통은 쇼만 하고 말 안 통해 숨 막히고 대기는 미세먼지로 숨 막히고 물가는 쳐올라서 기막히다
# 3.작성일자: 2019.01.15. 19:49
# 4.공감: 2
# 5.비공감: 0
#
#
# 총 75건 중 62번째 댓글 수집 중입니다 ==================
# 1.작성자ID: nada****
# 2.리뷰: 물타기 하느라 애쓴다
# 3.작성일자: 2019.01.15. 18:50
# 4.공감: 2
# 5.비공감: 0
#
#
# 총 75건 중 63번째 댓글 수집 중입니다 ==================
# 1.작성자ID: cale****
# 2.리뷰: KBS수신료 거부운동을 펼쳐야 합니다. 쓰래기뉴스 중국 딱갈이뉴스
# 3.작성일자: 2019.01.15. 18:43
# 4.공감: 2
# 5.비공감: 0
#
#
# 총 75건 중 64번째 댓글 수집 중입니다 ==================
# 1.작성자ID: ghrb****
# 2.리뷰 : 작성자에 의해 삭제된 댓글입니다
# 3.작성일자: 2020.06.06. 15:01
# 4.공감 : 0
# 5.비공감 : 0
#
#
# 총 75건 중 65번째 댓글 수집 중입니다 ==================
# 1.작성자ID: sanj****
# 2.리뷰: KBSㅋ 반중국 공연 허가 했다가 무슨 높은 중국 공산당 간부 놈도 아닌 놈이 아이템 수입 100억원 안해준다고 협박하니까 바로 취소시켜서 저 단체에 고소 당함. 한국 법원은 KBS 손 들어줬고.ㅋ 한심한 KBS, 시청료가 너무 아깝다
# 3.작성일자: 2019.01.15. 18:16
# 4.공감: 2
# 5.비공감: 0
#
#
# 총 75건 중 66번째 댓글 수집 중입니다 ==================
# 1.작성자ID: crak****
# 2.리뷰: 개비에스 이정훈은 미세먼지 국내책임 신봉론자임
# 3.작성일자: 2019.01.15. 18:03
# 4.공감: 2
# 5.비공감: 0
#
#
# 총 75건 중 67번째 댓글 수집 중입니다 ==================
# 1.작성자ID: scwa****
# 2.리뷰: 일제시대였으면 친일할 놈들이네. 중국눈치보느라 힘들지?
# 3.작성일자: 2019.01.15. 17:44
# 4.공감: 2
# 5.비공감: 0
#
#
# 총 75건 중 68번째 댓글 수집 중입니다 ==================
# 1.작성자ID: dark****
# 2.리뷰 : 작성자에 의해 삭제된 댓글입니다
# 3.작성일자: 2020.05.22. 19:57
# 4.공감 : 0
# 5.비공감 : 0
#
#
# 총 75건 중 69번째 댓글 수집 중입니다 ==================
# 1.작성자ID: wnsh****
# 2.리뷰: 충남지역 어느 공장에서 뿜어내는 에서 거른다 어떻게든 자국공장에서 발생되는 미세먼지로 몰아가네
# 3.작성일자: 2019.01.15. 17:40
# 4.공감: 2
# 5.비공감: 0
#
#
# 총 75건 중 70번째 댓글 수집 중입니다 ==================
# 1.작성자ID: lady****
# 2.리뷰: 대한민국 공장 굴뚝연기는 하루이틀 일 아니야ㅡ웃긴건 그렇게 국내서 연기 내뿜어도 미세먼지 모르고 살았어ㅡ여태 파란하늘 보고 살았다구~중국이 피해를 주기 시작하면서부터 우리는 희뿌연 세상에 살기 시작한거야
# 3.작성일자: 2019.01.15. 17:38
# 4.공감: 2
# 5.비공감: 0
#
#
# 총 75건 중 71번째 댓글 수집 중입니다 ==================
# 1.작성자ID: jsh2****
# 2.리뷰: 한국도 잘못이 크면 1년 내내 비오는 날 제외하고 스모그여야 하는데 바람 방향이 바뀌는 계절인 여름 가을엔 개청렴함ㅋㅋㅋㅋㅋ 중국 따까리 짓 졸라 하네ㅋ
# 3.작성일자: 2019.01.15. 17:35
# 4.공감: 2
# 5.비공감: 0
#
#
# 총 75건 중 72번째 댓글 수집 중입니다 ==================
# 1.작성자ID: ghae****
# 2.리뷰 : 작성자에 의해 삭제된 댓글입니다
# 3.작성일자: 2019.01.17. 17:41
# 4.공감 : 0
# 5.비공감 : 0
#
#
# 총 75건 중 73번째 댓글 수집 중입니다 ==================
# 1.작성자ID: amio****
# 2.리뷰: 이제 여름이 제일 살기좋은 계절이 되었구나..
# 3.작성일자: 2019.01.15. 17:33
# 4.공감: 2
# 5.비공감: 0
#
#
# 총 75건 중 74번째 댓글 수집 중입니다 ==================
# 1.작성자ID: huwa****
# 2.리뷰 : 작성자에 의해 삭제된 댓글입니다
# 3.작성일자: 2020.09.09. 18:44
# 4.공감 : 0
# 5.비공감 : 0
#
#
# 총 75건 중 75번째 댓글 수집 중입니다 ==================
# 1.작성자ID: luv2****
# 2.리뷰: 충남공장사진 장난하냐 이것들이 누굴 바보로아나
# 3.작성일자: 2019.01.15. 17:31
# 4.공감: 2
# 5.비공감: 0
#
#
# ========================================================================================================================
# 1.요청된 총 75 건의 리뷰 중에서 실제 크롤링 된 리뷰수는 75 건입니다
# 2.총 소요시간은 41.5 초 입니다
# 3.파일 저장 완료: txt 파일명 : c:\py_temp\2022-03-21-15-00-19-뉴스기사댓글\2022-03-21-15-00-19-뉴스기사댓글.txt
# 4.파일 저장 완료: csv 파일명 : c:\py_temp\2022-03-21-15-00-19-뉴스기사댓글\2022-03-21-15-00-19-뉴스기사댓글.csv
# 5.파일 저장 완료: xls 파일명 : c:\py_temp\2022-03-21-15-00-19-뉴스기사댓글\2022-03-21-15-00-19-뉴스기사댓글.xls
# ========================================================================================================================
